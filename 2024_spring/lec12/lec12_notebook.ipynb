# %% [markdown]
# # Speech Understanding
# # Lecture 12: Text-to-Speech Synthesis

# %% [markdown]
# ### Mark Hasegawa-Johnson, KCGI

# %% [markdown]
# 1. <a href="#section1">Installing gTTs, the Google speech synthesizer</a>
# 1. <a href="#section2">Using gTTs</a>
# 1. <a href="#section3">Use SpeechRecognizer to check the output</a>
# 1. <a href="#section4">Create an electronic parrot</a>
# 1. <a href="#homework">Homework</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## 1. Installing gTTs, the Google speech synthesizer

# %% [markdown]
# For speech synthesis, we will use Google's text-to-speech synthesis system (gTTs).  You need to be connected to the internet in order to use it. Documentation for gTTs is here: https://gtts.readthedocs.io/en/latest/
#
# gTTs is installed like this (either in the window below, or in a terminal):

# %%
# !pip install gTTs
# Out:
# Requirement already satisfied: gTTs in /Users/jhasegaw/anaconda3/lib/python3.10/site-packages (2.3.2)
# Requirement already satisfied: click<8.2,>=7.1 in /Users/jhasegaw/anaconda3/lib/python3.10/site-packages (from gTTs) (8.1.7)
# Requirement already satisfied: requests<3,>=2.27 in /Users/jhasegaw/anaconda3/lib/python3.10/site-packages (from gTTs) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jhasegaw/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.27->gTTs) (1.26.18)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jhasegaw/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.27->gTTs) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jhasegaw/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.27->gTTs) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jhasegaw/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.27->gTTs) (2024.6.2)

# %% [markdown]
# <a id="section2"></a>

# %% [markdown]
# ## 2. Using gTTs

# %% [markdown]
# gTTs can't play the audio directly.  We need to create the audio output, save it to a file, and then play back the file.

# %%
import gtts, soundfile, IPython

#desired_text = "これは合成音声です"
desired_text = "Hello world!"
tts = gtts.gTTS(text=desired_text, lang="en")
tts.save("speech.mp3")
    
speech_wave, speech_rate = soundfile.read("speech.mp3")
IPython.display.Audio(data=speech_wave, rate=speech_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <a id="section3"></a>

# %% [markdown]
# ## 3. Use SpeechRecognizer to check the output
#
# Often, in the real world, you need to generate synthetic speech prompts for a customer, but you don't have time to listen to all of them to make sure they're OK.
#
# When that happens, you can use `SpeechRecognizer` to check each of the files automatically.  If `SpeechRecognizer` detects any mistake, you can check manually to see if it's OK.
#
# First, we need to convert the file from `mp3` format to a format that `SpeechRecognizer` can handle.  `SpeechRecognizer` can handle wav and flac files.  We can use librosa to read in the mp3, then use soundfile to write it out, as shown [here](https://librosa.org/doc/main/ioformats.html#write-out-audio-files).

# %%
# !pip install soundfile
# Out:
# Requirement already satisfied: soundfile in /Users/jhasegaw/anaconda3/lib/python3.10/site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in /Users/jhasegaw/anaconda3/lib/python3.10/site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in /Users/jhasegaw/anaconda3/lib/python3.10/site-packages (from cffi>=1.0->soundfile) (2.21)

# %%
import soundfile
data, samplerate = soundfile.read('speech.mp3')
soundfile.write('speech.wav',data,samplerate)

# %% [markdown]
# Now we can call `speech_recognition` to check the file content:

# %%
import speech_recognition

r = speech_recognition.Recognizer()

with speech_recognition.AudioFile("speech.wav") as source:
    audio = r.record(source)
    text = r.recognize_google(audio, language="en")
    print('The person in this audio file said "%s"'%(text))
    if text == desired_text:
        print('This matches the desired text')
    else:
        print('This does not match the desired text, which was "%s"'%(desired_text))
# Out:
# The person in this audio file said "hello world"
# This does not match the desired text, which was "Hello world!"

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## 4. Create an electronic parrot

# %% [markdown]
# Now that we have both speech input and speech output, let's create our first speech app!
#
# This app will just be an electronic parrot.  The electronic parrot will listen to what you say, and try to repeat it.

# %%
import speech_recognition, gtts, IPython, soundfile

def electronic_parrot(L='en'):
    print("Hello!  I'm an electronic parrot 🦜.")
    print("Please say something, and I will try to repeat it.")
    
    r = speech_recognition.Recognizer()

    while True:
        with speech_recognition.Microphone() as source:
            print("Listening...")
            r.adjust_for_ambient_noise(source)
            try:
                audio = r.listen(source)
                text = r.recognize_google(audio, language=L)
            except speech_recognition.UnknownValueError:
                print('I did not understand that, I will try again')
                continue
            except sr.RequestError:
                print('Sorry, I could not reach the internet, I will try again')
                continue
            except sr.WaitTimeoutError:
                continue
            break
            
    print('I heard you say "%s", and now I will try to repeat it'%(text))
    gtts.gTTS(text='You said "%s"'%(text), lang=L).save("parrot.mp3")
    speech_wave, speech_rate = soundfile.read("parrot.mp3")
    return IPython.display.Audio(data=speech_wave, rate=speech_rate)

# %%
electronic_parrot('en')
# Out:
# Hello!  I'm an electronic parrot 🦜.
# Please say something, and I will try to repeat it.
# Listening...
# ||PaMacCore (AUHAL)|| Error on line 1277: err='-66748', msg=Unknown Error
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[25], line 12, in electronic_parrot(L)
#      11 print("Listening...")
# ---> 12 r.adjust_for_ambient_noise(source)
#      13 try:
#
# File ~/anaconda3/lib/python3.10/site-packages/speech_recognition/__init__.py:383, in Recognizer.adjust_for_ambient_noise(self, source, duration)
#     382 assert isinstance(source, AudioSource), "Source must be an audio source"
# --> 383 assert source.stream is not None, "Audio source must be entered before adjusting, see documentation for ``AudioSource``; are you using ``source`` outside of a ``with`` statement?"
#     384 assert self.pause_threshold >= self.non_speaking_duration >= 0
#
# AssertionError: Audio source must be entered before adjusting, see documentation for ``AudioSource``; are you using ``source`` outside of a ``with`` statement?
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 electronic_parrot('en')
#
# Cell In[25], line 10, in electronic_parrot(L)
#       7 r = speech_recognition.Recognizer()
#       9 while True:
# ---> 10     with speech_recognition.Microphone() as source:
#      11         print("Listening...")
#      12         r.adjust_for_ambient_noise(source)
#
# File ~/anaconda3/lib/python3.10/site-packages/speech_recognition/__init__.py:189, in Microphone.__exit__(self, exc_type, exc_value, traceback)
#     187 def __exit__(self, exc_type, exc_value, traceback):
#     188     try:
# --> 189         self.stream.close()
#     190     finally:
#     191         self.stream = None
#
# AttributeError: 'NoneType' object has no attribute 'close'

# %% [markdown]
# <a id='homework'></a>

# %% [markdown]
# ## Homework

# %% [markdown]
# Edit the text file called `homework12.py`.
#
# This file should `def` a function called `synthesize`, with a signature as shown here:

# %%
import homework12, importlib
importlib.reload(homework12)
help(homework12.synthesize)
# Out:
# Help on function synthesize in module homework12:
#
# synthesize(text, lang, filename)
#     Use gtts.gTTs(text=text, lang=lang) to synthesize speech, then write it to filename.
#
#     @params:
#     text (str) - the text you want to synthesize
#     lang (str) - the language in which you want to synthesize it
#     filename (str) - the filename in which it should be saved

# %% [markdown]
# Test whether your code works by running the following block:

# %%
import homework12, soundfile, IPython, importlib
importlib.reload(homework12)

homework12.synthesize("This is speech synthesis!","en","english.mp3")
#homework12.synthesize("これは合成音声です","ja","japanese.mp3")
y, sr = soundfile.read("english.mp3")
IPython.display.Audio(data=y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Receiving your grade
#
# In order to receive a grade for your homework, you need to:
#
# 1. Run the following code block on your machine.  The result may list some errors, and then in the very last line, it will show a score.  That score (between 0% and 100%) is the grade you have earned so far.  If you want to earn a higher grade, please continue editing `homework3.py`, and then run this code block again.
# 1. When you are happy with your score (e.g., when it reaches 100%), choose `File` $\Rightarrow$ `Save and Checkpoint`.  Then use `GitHub Desktop` to commit and push your changes.
# 1. Make sure that the 100% shows on your github repo on github.com.  If it doesn't, you will not receive credit.

# %%
import importlib, grade
importlib.reload(grade)
# Out:
# FF..
# ======================================================================
# FAIL: test_method_creates_correct_synthesis_english (grade.Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/jhasegaw/Documents/GitHub/intro_speech_understanding/2024_spring/lec12/grade.py", line 49, in test_method_creates_correct_synthesis_english
#     self.assertEqual(int(len(hypothesis)/1024), int(len(reference)/1024),
# AssertionError: 16 != 8 :
#                          homework12.synthesize("This is speech synthesis!","en","english.mp3")
#                          creates a file with the wrong content.
#
#
# ======================================================================
# FAIL: test_method_creates_correct_synthesis_spanish (grade.Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/jhasegaw/Documents/GitHub/intro_speech_understanding/2024_spring/lec12/grade.py", line 63, in test_method_creates_correct_synthesis_spanish
#     self.assertEqual(int(len(hypothesis)/1024), int(len(reference)/1024),
# AssertionError: 16 != 8 :
#                          homework12.synthesize, when called with a non-English text string,
#                          creates a file with the wrong content.
#
#
# ----------------------------------------------------------------------
# Ran 4 tests in 1.030s
#
# FAILED (failures=2)
# 2 successes out of 4 tests run
# Score: 50%
# <module 'grade' from '/Users/jhasegaw/Documents/GitHub/intro_speech_understanding/2024_spring/lec12/grade.py'>

# %%
# !conda update pyaudio
# Out:
# Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (/Users/jhasegaw/anaconda3/lib/python3.10/site-packages/conda/plugins/types.py))
# Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (/Users/jhasegaw/anaconda3/lib/python3.10/site-packages/conda/plugins/types.py))
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/jhasegaw/anaconda3
#
#   added / updated specs:
#     - pyaudio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anaconda-anon-usage-0.4.4  |py310hfb7c958_100          26 KB
#     anaconda-navigator-2.6.1   |  py310hecd8cb5_0         6.5 MB
#     annotated-types-0.6.0      |  py310hecd8cb5_0          23 KB
#     anyio-4.2.0                |  py310hecd8cb5_0         194 KB
#     beautifulsoup4-4.12.3      |  py310hecd8cb5_0         222 KB
#     bottleneck-1.3.7           |  py310h7b7cdfe_0         133 KB
#     brotli-1.0.9               |       h6c40b1e_8          20 KB
#     brotli-bin-1.0.9           |       h6c40b1e_8          17 KB
#     bzip2-1.0.8                |       h6c40b1e_6         151 KB
#     cffi-1.16.0                |  py310h6c40b1e_1         242 KB
#     comm-0.2.1                 |  py310hecd8cb5_0          16 KB
#     conda-repo-cli-1.0.88      |  py310hecd8cb5_0         140 KB
#     cryptography-42.0.5        |  py310h30e54ef_1         1.2 MB
#     curl-8.7.1                 |       h04015c4_0          80 KB
#     exceptiongroup-1.2.0       |  py310hecd8cb5_0          31 KB
#     expat-2.6.2                |       hcec6c5f_0         150 KB
#     fonttools-4.51.0           |  py310h6c40b1e_0         2.4 MB
#     idna-3.7                   |  py310hecd8cb5_0         132 KB
#     ipykernel-6.28.0           |  py310hecd8cb5_0         203 KB
#     ipython-8.25.0             |  py310hecd8cb5_0         1.1 MB
#     ipywidgets-8.1.2           |  py310hecd8cb5_0         204 KB
#     jinja2-3.1.4               |  py310hecd8cb5_0         280 KB
#     jsonpatch-1.33             |  py310hecd8cb5_1          32 KB
#     jupyter_core-5.7.2         |  py310hecd8cb5_0          81 KB
#     jupyter_events-0.10.0      |  py310hecd8cb5_0          38 KB
#     jupyter_server-2.14.1      |  py310hecd8cb5_0         501 KB
#     jupyterlab-4.0.11          |  py310hecd8cb5_0         4.5 MB
#     jupyterlab_widgets-3.0.10  |  py310hecd8cb5_0         196 KB
#     keyring-24.3.1             |  py310hecd8cb5_0          67 KB
#     libbrotlicommon-1.0.9      |       h6c40b1e_8          68 KB
#     libbrotlidec-1.0.9         |       h6c40b1e_8          31 KB
#     libbrotlienc-1.0.9         |       h6c40b1e_8         300 KB
#     libcurl-8.7.1              |       hf20ceda_0         381 KB
#     libffi-3.4.4               |       hecd8cb5_1         129 KB
#     libiconv-1.16              |       h6c40b1e_3         720 KB
#     libpq-12.17                |       h04015c4_0         2.5 MB
#     libssh2-1.11.0             |       hf20ceda_0         270 KB
#     libxml2-2.10.4             |       h45904e2_2         666 KB
#     lz4-c-1.9.4                |       hcec6c5f_1         167 KB
#     navigator-updater-0.5.1    |  py310hecd8cb5_0         2.2 MB
#     nest-asyncio-1.6.0         |  py310hecd8cb5_0          15 KB
#     packaging-23.2             |  py310hecd8cb5_0         149 KB
#     pillow-10.3.0              |  py310h6c40b1e_0         745 KB
#     pkginfo-1.10.0             |  py310hecd8cb5_0          53 KB
#     pycosat-0.6.6              |  py310h6c40b1e_1          95 KB
#     pydantic-2.5.3             |  py310hecd8cb5_0         545 KB
#     pydantic-core-2.14.6       |  py310hf2ad997_0         1.6 MB
#     pyjwt-2.8.0                |  py310hecd8cb5_0          76 KB
#     pyopenssl-24.0.0           |  py310hecd8cb5_0          98 KB
#     python-dateutil-2.9.0post0 |  py310hecd8cb5_2         280 KB
#     pytz-2024.1                |  py310hecd8cb5_0         217 KB
#     qtconsole-5.5.1            |  py310hecd8cb5_0         197 KB
#     reproc-14.2.4              |       hcec6c5f_2          28 KB
#     reproc-cpp-14.2.4          |       hcec6c5f_2          20 KB
#     requests-2.32.2            |  py310hecd8cb5_0         103 KB
#     semver-3.0.2               |  py310hecd8cb5_0          39 KB
#     sniffio-1.3.0              |  py310hecd8cb5_0          17 KB
#     sqlite-3.45.3              |       h6c40b1e_0         1.2 MB
#     tk-8.6.14                  |       h4d00af3_0         3.4 MB
#     tornado-6.4.1              |  py310h46256e1_0         668 KB
#     tqdm-4.66.4                |  py310h20db666_0         135 KB
#     traitlets-5.14.3           |  py310hecd8cb5_0         182 KB
#     typing-extensions-4.11.0   |  py310hecd8cb5_0          10 KB
#     typing_extensions-4.11.0   |  py310hecd8cb5_0          62 KB
#     tzdata-2024a               |       h04d1e81_0         116 KB
#     ujson-5.10.0               |  py310h6d0c2b6_0         147 KB
#     unicodedata2-15.1.0        |  py310h6c40b1e_0         517 KB
#     urllib3-2.2.2              |  py310hecd8cb5_0         181 KB
#     websocket-client-1.8.0     |  py310hecd8cb5_0          90 KB
#     widgetsnbextension-4.0.10  |  py310hecd8cb5_0         948 KB
#     xz-5.4.6                   |       h6c40b1e_1         371 KB
#     zstandard-0.22.0           |  py310h2d76c9a_0         443 KB
#     zstd-1.5.5                 |       hc035e20_2         599 KB
#     ------------------------------------------------------------
#                                            Total:        39.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   annotated-types    pkgs/main/osx-64::annotated-types-0.6.0-py310hecd8cb5_0
#   pydantic-core      pkgs/main/osx-64::pydantic-core-2.14.6-py310hf2ad997_0
#   unicodedata2       pkgs/main/osx-64::unicodedata2-15.1.0-py310h6c40b1e_0
#
# The following packages will be REMOVED:
#
#   giflib-5.2.1-h6c40b1e_3
#   libwebp-1.3.2-hf6ce154_0
#   munkres-1.1.4-py_0
#   pathlib-1.0.1-pyhd3eb1b0_1
#
# The following packages will be UPDATED:
#
#   anaconda-anon-usa~                0.4.3-py310hfb7c958_100 --> 0.4.4-py310hfb7c958_100
#   anyio                               3.5.0-py310hecd8cb5_0 --> 4.2.0-py310hecd8cb5_0
#   beautifulsoup4                     4.12.2-py310hecd8cb5_0 --> 4.12.3-py310hecd8cb5_0
#   bottleneck                          1.3.5-py310h4e76f89_0 --> 1.3.7-py310h7b7cdfe_0
#   brotli                                   1.0.9-hca72f7f_7 --> 1.0.9-h6c40b1e_8
#   brotli-bin                               1.0.9-hca72f7f_7 --> 1.0.9-h6c40b1e_8
#   bzip2                                    1.0.8-h1de35cc_0 --> 1.0.8-h6c40b1e_6
#   cffi                               1.16.0-py310h6c40b1e_0 --> 1.16.0-py310h6c40b1e_1
#   comm                                0.1.2-py310hecd8cb5_0 --> 0.2.1-py310hecd8cb5_0
#   conda-repo-cli                     1.0.75-py310hecd8cb5_0 --> 1.0.88-py310hecd8cb5_0
#   cryptography                       41.0.7-py310h30e54ef_0 --> 42.0.5-py310h30e54ef_1
#   curl                                     8.5.0-h04015c4_0 --> 8.7.1-h04015c4_0
#   exceptiongroup                      1.0.4-py310hecd8cb5_0 --> 1.2.0-py310hecd8cb5_0
#   expat                                    2.5.0-hcec6c5f_0 --> 2.6.2-hcec6c5f_0
#   fonttools          pkgs/main/noarch::fonttools-4.25.0-py~ --> pkgs/main/osx-64::fonttools-4.51.0-py310h6c40b1e_0
#   idna                                  3.4-py310hecd8cb5_0 --> 3.7-py310hecd8cb5_0
#   ipykernel                          6.25.0-py310h20db666_0 --> 6.28.0-py310hecd8cb5_0
#   ipython                            8.20.0-py310hecd8cb5_0 --> 8.25.0-py310hecd8cb5_0
#   ipywidgets                          8.0.4-py310hecd8cb5_0 --> 8.1.2-py310hecd8cb5_0
#   jinja2                              3.1.2-py310hecd8cb5_0 --> 3.1.4-py310hecd8cb5_0
#   jsonpatch          pkgs/main/noarch::jsonpatch-1.32-pyhd~ --> pkgs/main/osx-64::jsonpatch-1.33-py310hecd8cb5_1
#   jupyter_core                        5.5.0-py310hecd8cb5_0 --> 5.7.2-py310hecd8cb5_0
#   jupyter_events                      0.8.0-py310hecd8cb5_0 --> 0.10.0-py310hecd8cb5_0
#   jupyter_server                     2.10.0-py310hecd8cb5_0 --> 2.14.1-py310hecd8cb5_0
#   jupyterlab                          4.0.8-py310hecd8cb5_0 --> 4.0.11-py310hecd8cb5_0
#   jupyterlab_widgets                  3.0.9-py310hecd8cb5_0 --> 3.0.10-py310hecd8cb5_0
#   keyring                           23.13.1-py310hecd8cb5_0 --> 24.3.1-py310hecd8cb5_0
#   libbrotlicommon                          1.0.9-hca72f7f_7 --> 1.0.9-h6c40b1e_8
#   libbrotlidec                             1.0.9-hca72f7f_7 --> 1.0.9-h6c40b1e_8
#   libbrotlienc                             1.0.9-hca72f7f_7 --> 1.0.9-h6c40b1e_8
#   libcurl                                  8.5.0-hf20ceda_0 --> 8.7.1-hf20ceda_0
#   libffi                                   3.4.4-hecd8cb5_0 --> 3.4.4-hecd8cb5_1
#   libiconv                                  1.16-hca72f7f_2 --> 1.16-h6c40b1e_3
#   libpq                                    12.15-h04015c4_1 --> 12.17-h04015c4_0
#   libssh2                                 1.10.0-h04015c4_2 --> 1.11.0-hf20ceda_0
#   libxml2                                 2.10.4-h1bd7e62_1 --> 2.10.4-h45904e2_2
#   lz4-c                                    1.9.4-hcec6c5f_0 --> 1.9.4-hcec6c5f_1
#   navigator-updater                   0.4.0-py310hecd8cb5_1 --> 0.5.1-py310hecd8cb5_0
#   nest-asyncio                        1.5.6-py310hecd8cb5_0 --> 1.6.0-py310hecd8cb5_0
#   packaging                            23.1-py310hecd8cb5_0 --> 23.2-py310hecd8cb5_0
#   pillow                             10.0.1-py310h7d39338_0 --> 10.3.0-py310h6c40b1e_0
#   pkginfo                             1.9.6-py310hecd8cb5_0 --> 1.10.0-py310hecd8cb5_0
#   pycosat                             0.6.6-py310h6c40b1e_0 --> 0.6.6-py310h6c40b1e_1
#   pydantic                          1.10.12-py310h6c40b1e_1 --> 2.5.3-py310hecd8cb5_0
#   pyjwt                               2.4.0-py310hecd8cb5_0 --> 2.8.0-py310hecd8cb5_0
#   pyopenssl                          23.2.0-py310hecd8cb5_0 --> 24.0.0-py310hecd8cb5_0
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8~ --> pkgs/main/osx-64::python-dateutil-2.9.0post0-py310hecd8cb5_2
#   pytz                         2023.3.post1-py310hecd8cb5_0 --> 2024.1-py310hecd8cb5_0
#   qtconsole                           5.5.0-py310hecd8cb5_0 --> 5.5.1-py310hecd8cb5_0
#   reproc                                  14.2.4-he9d5cce_1 --> 14.2.4-hcec6c5f_2
#   reproc-cpp                              14.2.4-he9d5cce_1 --> 14.2.4-hcec6c5f_2
#   requests                           2.31.0-py310hecd8cb5_0 --> 2.32.2-py310hecd8cb5_0
#   semver             pkgs/main/noarch::semver-2.13.0-pyhd3~ --> pkgs/main/osx-64::semver-3.0.2-py310hecd8cb5_0
#   sniffio                             1.2.0-py310hecd8cb5_1 --> 1.3.0-py310hecd8cb5_0
#   sqlite                                  3.41.2-h6c40b1e_0 --> 3.45.3-h6c40b1e_0
#   tk                                      8.6.12-h5d9f67b_0 --> 8.6.14-h4d00af3_0
#   tornado                             6.3.3-py310h6c40b1e_0 --> 6.4.1-py310h46256e1_0
#   tqdm                               4.65.0-py310h20db666_0 --> 4.66.4-py310h20db666_0
#   traitlets                           5.7.1-py310hecd8cb5_0 --> 5.14.3-py310hecd8cb5_0
#   typing-extensions                   4.7.1-py310hecd8cb5_0 --> 4.11.0-py310hecd8cb5_0
#   typing_extensions                   4.7.1-py310hecd8cb5_0 --> 4.11.0-py310hecd8cb5_0
#   tzdata                                   2023d-h04d1e81_0 --> 2024a-h04d1e81_0
#   ujson                               5.4.0-py310he9d5cce_0 --> 5.10.0-py310h6d0c2b6_0
#   urllib3                           1.26.18-py310hecd8cb5_0 --> 2.2.2-py310hecd8cb5_0
#   websocket-client                   0.58.0-py310hecd8cb5_4 --> 1.8.0-py310hecd8cb5_0
#   widgetsnbextension                  4.0.5-py310hecd8cb5_0 --> 4.0.10-py310hecd8cb5_0
#   xz                                       5.4.5-h6c40b1e_0 --> 5.4.6-h6c40b1e_1
#   zstandard                          0.19.0-py310h6c40b1e_0 --> 0.22.0-py310h2d76c9a_0
#   zstd                                     1.5.5-hc035e20_0 --> 1.5.5-hc035e20_2
#
# The following packages will be DOWNGRADED:
#
#   anaconda-navigator                  2.6.1-py310hecd8cb5_1 --> 2.6.1-py310hecd8cb5_0
#
#
# Proceed ([y]/n)?
